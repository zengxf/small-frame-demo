# %% [markdown]
# ### test 1

# %%
print('ok ...')

name = 'zxf'

print(f'name: {name} ...')
# Out:
# ok ...
# name: zxf ...

# %% [markdown]
# ### test 2

# %%
age = 32
print(f'age: {age} ...')

name1 = name + '-2'
print(f'name1: {name1} ...')
# Out:
# age: 32 ...
# name1: zxf-2 ...

# %% [markdown]
# ### test 3
# - 测试 `test 3`
# - notebook - **001**

# %%
year = 2025
month = 12
print(f'year: {year} month: {month} ...')
# Out:
# year: 2025 month: 12 ...
