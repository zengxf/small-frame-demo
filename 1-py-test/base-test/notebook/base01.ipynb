# %% [markdown]
# ### test 1

# %%
print('ok ...')

name = 'zxf'

print(f'name: {name} ...')

# %% [markdown]
# ### test 2

# %%
age = 32
print(f'age: {age} ...')

# name1 = name + '-2' # 上面运行完之后，可以识别
# print(f'name1: {name1} ...')

name1 = 'xx' + '-2'
print(f'name1: {name1} ...')
# Out:
# age: 32 ...
# name1: xx-2 ...

# %% [markdown]
# ### test 3
# - 测试 `test 3`
# - notebook - **001**

# %%
year = 2025
month = 12
print(f'year: {year} month: {month} ...')
# Out:
# year: 2025 month: 12 ...

# %% [markdown]
# ### test 4
# - [ ] xx
# - [ ] bb

# %%
print('xx', 'bb')
# Out:
# xx bb

# %% [markdown]
# ### test out

# %% [markdown]
# - py 代码
# ```bash
# # 只保留代码和输出（无 Markdown）
# jupyter nbconvert --to script base01.ipynb
# ```
# - html
# ```bash
# # 导出为 HTML
# jupyter nbconvert --to html base01.ipynb
# ```
# - markdown
# ```bash
# jupyter nbconvert --to markdown base01.ipynb
# ```
# - pdf (需要安装 panddoc，没试了)
# ```bash
# # 导出为 PDF
# jupyter nbconvert --to pdf base01.ipynb
# ```

# %% [markdown]
# ### test JS
# - 浏览器打开才有用
# - ref: http://localhost:8888/notebooks/notebook/base01.ipynb
# - 但打开后会改格式，没有保持 PyCharm 格式

# %%
# %%javascript
#
# alert("Hello from JavaScript!");
# console.log("This is printed in the browser console");
